# %%
import requests
import pandas as pd

# %% [markdown]
# ### Pokemon API

# %% [markdown]
# [PokeAPI](https://pokeapi.co/) is a full RESTful API linked to an extensive database detailing everything about the Pokémon main game series.
#
# In the documentation we see that we can get lot's of data. Let's look at the endpoint *pokemon*: ```https://pokeapi.co/api/v2/pokemon/{id or name}/```

# %%
url = 'https://api.coincap.io/v2/assets'

response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'data': [{'id': 'bitcoin',
#    'rank': '1',
#    'symbol': 'BTC',
#    'name': 'Bitcoin',
#    'supply': '19719981.0000000000000000',
#    'maxSupply': '21000000.0000000000000000',
#    'marketCapUsd': '1134009832338.0065305214175978',
#    'volumeUsd24Hr': '11498840489.1653368480747578',
#    'priceUsd': '57505.6249972049430738',
#    'changePercent24Hr': '0.0751097233134673',
#    'vwap24Hr': '58109.9663121234943209',
#    'explorer': 'https://blockchain.info/'},
#   {'id': 'ethereum',
#    'rank': '2',
#    'symbol': 'ETH',
#    'name': 'Ethereum',
#    'supply': '120209171.4182295800000000',
#    'maxSupply': None,
#    'marketCapUsd': '374418791731.4609034481505373',
#    'volumeUsd24Hr': '7839490709.5883600922375026',
#    'priceUsd': '3114.7273316508421784',
#    'changePercent24Hr': '0.2668966572573288',
#    'vwap24Hr': '3131.2178350280849755',
#    'explorer': 'https://etherscan.io/'},
#   {'id': 'tether',
#    'rank': '3',
#    'symbol': 'USDT',
#    'name': 'Tether',
#    'supply': '112259808785.1427800000000000',
#    'maxSupply': None,
#    'marketCapUsd': '112325975695.2843195725085213',
#    'volumeUsd24Hr': '14929475226.6693824492293595',
#    'priceUsd': '1.0005894087194481',
#    'changePercent24Hr': '0.0197085115839986',
#    'vwap24Hr': '1.0002086623431707',
#    'explorer': 'https://www.omniexplorer.info/asset/31'},
#   {'id': 'binance-coin',
#    'rank': '4',
#    'symbol': 'BNB',
#    'name': 'BNB',
#    'supply': '166801148.0000000000000000',
#    'maxSupply': '166801148.0000000000000000',
#    'marketCapUsd': '87729530955.1285150002027308',
#    'volumeUsd24Hr': '294138518.8807696699419142',
#    'priceUsd': '525.9528007272978421',
#    'changePercent24Hr': '0.4462434656171022',
#    'vwap24Hr': '530.7011370922360641',
#    'explorer': 'https://etherscan.io/token/0xB8c77482e45F1F44dE1745F52C74426C631bDD52'},
#   {'id': 'solana',
#    'rank': '5',
#    'symbol': 'SOL',
#    'name': 'Solana',
#    'supply': '463960292.5906939500000000',
#    'maxSupply': None,
#    'marketCapUsd': '63710804350.0946055823147606',
#    'volumeUsd24Hr': '689868112.5118536482234487',
#    'priceUsd': '137.3195192940795811',
#    'changePercent24Hr': '-2.8521368290586593',
#    'vwap24Hr': '141.2464694532299801',
#    'explorer': 'https://explorer.solana.com/'},
#   {'id': 'usd-coin',
#    'rank': '6',
#    'symbol': 'USDC',
#    'name': 'USDC',
#    'supply': '33908382580.8915520000000000',
#    'maxSupply': None,
#    'marketCapUsd': '33924316901.3749290146775089',
#    'volumeUsd24Hr': '1257439882.1626347551865811',
#    'priceUsd': '1.0004699227527401',
#    'changePercent24Hr': '0.0189530551164553',
#    'vwap24Hr': '1.0001766462168476',
#    'explorer': 'https://etherscan.io/token/0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48'},
#   {'id': 'xrp',
#    'rank': '7',
#    'symbol': 'XRP',
#    'name': 'XRP',
#    'supply': '45404028640.0000000000000000',
#    'maxSupply': '100000000000.0000000000000000',
#    'marketCapUsd': '20363391829.6585321872767040',
#    'volumeUsd24Hr': '485183569.1435153792715097',
#    'priceUsd': '0.4484930619508686',
#    'changePercent24Hr': '2.7877981029088141',
#    'vwap24Hr': '0.4446461826142228',
#    'explorer': 'https://xrpcharts.ripple.com/#/graph/'},
#   {'id': 'dogecoin',
#    'rank': '8',
#    'symbol': 'DOGE',
#    'name': 'Dogecoin',
#    'supply': '145075296383.7052000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '15572366214.9015031071341450',
#    'volumeUsd24Hr': '167440883.8872513428352784',
#    'priceUsd': '0.1073398890305530',
#    'changePercent24Hr': '-0.5712884651046039',
#    'vwap24Hr': '0.1087525918334452',
#    'explorer': 'http://dogechain.info/chain/Dogecoin'},
#   {'id': 'cardano',
#    'rank': '9',
#    'symbol': 'ADA',
#    'name': 'Cardano',
#    'supply': '35875143821.4130000000000000',
#    'maxSupply': '45000000000.0000000000000000',
#    'marketCapUsd': '14231694606.7438063835732680',
#    'volumeUsd24Hr': '125679629.7565048841561213',
#    'priceUsd': '0.3967006983327898',
#    'changePercent24Hr': '2.8609260126266254',
#    'vwap24Hr': '0.3933203603474655',
#    'explorer': 'https://cardanoexplorer.com/'},
#   {'id': 'tron',
#    'rank': '10',
#    'symbol': 'TRX',
#    'name': 'TRON',
#    'supply': '87136221841.2426900000000000',
#    'maxSupply': None,
#    'marketCapUsd': '11755876845.5499883638190520',
#    'volumeUsd24Hr': '160744450.2305163045896527',
#    'priceUsd': '0.1349137774985073',
#    'changePercent24Hr': '2.7397423156874442',
#    'vwap24Hr': '0.1335521630207054',
#    'explorer': 'https://tronscan.org/#/'},
#   {'id': 'avalanche',
#    'rank': '11',
#    'symbol': 'AVAX',
#    'name': 'Avalanche',
#    'supply': '394403840.1728880000000000',
#    'maxSupply': '715748719.0000000000000000',
#    'marketCapUsd': '9992335896.4946136702152289',
#    'volumeUsd24Hr': '93978332.6241801117014824',
#    'priceUsd': '25.3352905796111061',
#    'changePercent24Hr': '-2.9611665482917825',
#    'vwap24Hr': '25.6922413311917557',
#    'explorer': 'https://avascan.info/'},
#   {'id': 'shiba-inu',
#    'rank': '12',
#    'symbol': 'SHIB',
#    'name': 'Shiba Inu',
#    'supply': '589270749328708.9000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '9660545751.3389235758951816',
#    'volumeUsd24Hr': '85021926.5821451213574904',
#    'priceUsd': '0.0000163940697249',
#    'changePercent24Hr': '0.1843391572524133',
#    'vwap24Hr': '0.0000165298374349',
#    'explorer': 'https://etherscan.io/token/0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce'},
#   {'id': 'wrapped-bitcoin',
#    'rank': '13',
#    'symbol': 'WBTC',
#    'name': 'Wrapped Bitcoin',
#    'supply': '153281.8946827400000000',
#    'maxSupply': None,
#    'marketCapUsd': '8827904931.3909184440528264',
#    'volumeUsd24Hr': '18153762.4833209396423885',
#    'priceUsd': '57592.6135938151797564',
#    'changePercent24Hr': '0.0685934221392499',
#    'vwap24Hr': '58266.9011292662225576',
#    'explorer': 'https://etherscan.io/token/0x2260fac5e5542a773aa44fbcfedf7c193bc2c599'},
#   {'id': 'polkadot',
#    'rank': '14',
#    'symbol': 'DOT',
#    'name': 'Polkadot',
#    'supply': '1386692924.7393100000000000',
#    'maxSupply': None,
#    'marketCapUsd': '8240976378.1964439058032097',
#    'volumeUsd24Hr': '61494756.9155305371209161',
#    'priceUsd': '5.9428992758044816',
#    'changePercent24Hr': '-2.7018107146603980',
#    'vwap24Hr': '6.0987759488282567',
#    'explorer': 'https://polkascan.io/polkadot'},
#   {'id': 'chainlink',
#    'rank': '15',
#    'symbol': 'LINK',
#    'name': 'Chainlink',
#    'supply': '608099970.4527867000000000',
#    'maxSupply': None,
#    'marketCapUsd': '7615724698.0425810606632800',
#    'volumeUsd24Hr': '159842439.6017045962209970',
#    'priceUsd': '12.5238037626806153',
#    'changePercent24Hr': '-1.9861455246716343',
#    'vwap24Hr': '12.8204281974533310',
#    'explorer': 'https://etherscan.io/token/0x514910771af9ca656af840dff83e8264ecf986ca'},
#   {'id': 'bitcoin-cash',
#    'rank': '16',
#    'symbol': 'BCH',
#    'name': 'Bitcoin Cash',
#    'supply': '19731493.7500000000000000',
#    'maxSupply': '21000000.0000000000000000',
#    'marketCapUsd': '6893945009.9055325495980131',
#    'volumeUsd24Hr': '113396821.1332690133101149',
#    'priceUsd': '349.3878921308495739',
#    'changePercent24Hr': '3.8314805677001634',
#    'vwap24Hr': '347.3569581019886746',
#    'explorer': 'https://blockchair.com/bitcoin-cash/blocks'},
#   {'id': 'unus-sed-leo',
#    'rank': '17',
#    'symbol': 'LEO',
#    'name': 'UNUS SED LEO',
#    'supply': '926020477.9000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '5426802776.5515452698216476',
#    'volumeUsd24Hr': '2665014.0293999369227496',
#    'priceUsd': '5.8603485625482897',
#    'changePercent24Hr': '0.1279514374744724',
#    'vwap24Hr': '5.7388285459894835',
#    'explorer': 'https://eospark.com/account/bitfinexleo1'},
#   {'id': 'near-protocol',
#    'rank': '18',
#    'symbol': 'NEAR',
#    'name': 'NEAR Protocol',
#    'supply': '1096768596.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '5420172009.6019046322326016',
#    'volumeUsd24Hr': '91769662.9613921346341697',
#    'priceUsd': '4.9419467601184896',
#    'changePercent24Hr': '6.6683507910182045',
#    'vwap24Hr': '4.7623518655805293',
#    'explorer': 'https://explorer.nearprotocol.com/'},
#   {'id': 'multi-collateral-dai',
#    'rank': '19',
#    'symbol': 'DAI',
#    'name': 'Multi Collateral DAI',
#    'supply': '5347888595.7464075000000000',
#    'maxSupply': None,
#    'marketCapUsd': '5345771673.6329859430668766',
#    'volumeUsd24Hr': '109685852.5843267959846118',
#    'priceUsd': '0.9996041574023989',
#    'changePercent24Hr': '-0.0591436106899736',
#    'vwap24Hr': '1.0003217789252316',
#    'explorer': 'https://etherscan.io/token/0x89d24a6b4ccb1b6faa2625fe562bdd9a23260359'},
#   {'id': 'litecoin',
#    'rank': '20',
#    'symbol': 'LTC',
#    'name': 'Litecoin',
#    'supply': '74738793.6075049000000000',
#    'maxSupply': '84000000.0000000000000000',
#    'marketCapUsd': '5115811439.8148117166693664',
#    'volumeUsd24Hr': '142644312.2186230909545592',
#    'priceUsd': '68.4492108165511951',
#    'changePercent24Hr': '2.5608287336029957',
#    'vwap24Hr': '67.8651098352322748',
#    'explorer': 'http://explorer.litecoin.net/chain/Litecoin'},
#   {'id': 'polygon',
#    'rank': '21',
#    'symbol': 'MATIC',
#    'name': 'Polygon',
#    'supply': '9894059780.2208440000000000',
#    'maxSupply': None,
#    'marketCapUsd': '4985859261.9134792918029338',
#    'volumeUsd24Hr': '69547226.2577843267561334',
#    'priceUsd': '0.5039245135632474',
#    'changePercent24Hr': '-1.7937547725797602',
#    'vwap24Hr': '0.5125757177795015',
#    'explorer': 'https://etherscan.io/token/0x7D1AfA7B718fb893dB30A3aBc0Cfc608AaCfeBB0'},
#   {'id': 'uniswap',
#    'rank': '22',
#    'symbol': 'UNI',
#    'name': 'Uniswap',
#    'supply': '600034294.7100000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '4745935835.0568108459946590',
#    'volumeUsd24Hr': '75232696.8880602039365339',
#    'priceUsd': '7.9094409717873688',
#    'changePercent24Hr': '-1.9273581877934274',
#    'vwap24Hr': '7.9966022650096245',
#    'explorer': 'https://etherscan.io/token/0x1f9840a85d5af5bf1d1762f925bdaddc4201f984'},
#   {'id': 'internet-computer',
#    'rank': '23',
#    'symbol': 'ICP',
#    'name': 'Internet Computer',
#    'supply': '466123913.4144278000000000',
#    'maxSupply': None,
#    'marketCapUsd': '3443833360.7820398315635924',
#    'volumeUsd24Hr': '21168436.7889911116847443',
#    'priceUsd': '7.3882357494929670',
#    'changePercent24Hr': '2.7177883304036272',
#    'vwap24Hr': '7.3850881427908892',
#    'explorer': 'https://www.dfinityexplorer.org/#/'},
#   {'id': 'ethereum-classic',
#    'rank': '24',
#    'symbol': 'ETC',
#    'name': 'Ethereum Classic',
#    'supply': '147878551.3315075600000000',
#    'maxSupply': '210700000.0000000000000000',
#    'marketCapUsd': '3119269437.9998682787777763',
#    'volumeUsd24Hr': '65733650.5876703188196280',
#    'priceUsd': '21.0934541210593061',
#    'changePercent24Hr': '0.3958137109849329',
#    'vwap24Hr': '21.1040014427419142',
#    'explorer': 'http://gastracker.io/'},
#   {'id': 'monero',
#    'rank': '25',
#    'symbol': 'XMR',
#    'name': 'Monero',
#    'supply': '18446744.0737095500000000',
#    'maxSupply': None,
#    'marketCapUsd': '2931671834.8259926052677106',
#    'volumeUsd24Hr': '49800010.8638854506241047',
#    'priceUsd': '158.9262486166453189',
#    'changePercent24Hr': '0.5790182025889402',
#    'vwap24Hr': '157.9271056675913300',
#    'explorer': 'http://moneroblocks.info/'},
#   {'id': 'fetch',
#    'rank': '26',
#    'symbol': 'FET',
#    'name': 'Artificial Superintelligence Alliance',
#    'supply': '2520000000.0000000000000000',
#    'maxSupply': '2630547141.0000000000000000',
#    'marketCapUsd': '2929888218.7732971240000000',
#    'volumeUsd24Hr': '46504926.9214130347782367',
#    'priceUsd': '1.1626540550687687',
#    'changePercent24Hr': '-2.4550365460039820',
#    'vwap24Hr': '1.1963489827936485',
#    'explorer': 'https://etherscan.io/token/0x1d287cc25dad7ccaf76a26bc660c5f7c8e2a05bd'},
#   {'id': 'stellar',
#    'rank': '27',
#    'symbol': 'XLM',
#    'name': 'Stellar',
#    'supply': '29227062904.5475850000000000',
#    'maxSupply': '50001806812.0000000000000000',
#    'marketCapUsd': '2606740718.0015503409610107',
#    'volumeUsd24Hr': '28165740.5633796057559959',
#    'priceUsd': '0.0891892807195469',
#    'changePercent24Hr': '2.3071632680472135',
#    'vwap24Hr': '0.0885254652976805',
#    'explorer': 'https://dashboard.stellar.org/'},
#   {'id': 'filecoin',
#    'rank': '28',
#    'symbol': 'FIL',
#    'name': 'Filecoin',
#    'supply': '569587345.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '2391440129.5832188157933170',
#    'volumeUsd24Hr': '70499423.5561589108696909',
#    'priceUsd': '4.1985485642824786',
#    'changePercent24Hr': '6.3735882894560734',
#    'vwap24Hr': '4.0558218792963571',
#    'explorer': 'https://protocol.ai'},
#   {'id': 'stacks',
#    'rank': '29',
#    'symbol': 'STX',
#    'name': 'Stacks',
#    'supply': '1473817680.5993930000000000',
#    'maxSupply': '1818000000.0000000000000000',
#    'marketCapUsd': '2371378762.3980434399274128',
#    'volumeUsd24Hr': '35192336.7424064221917851',
#    'priceUsd': '1.6090041486227914',
#    'changePercent24Hr': '6.5112492392260431',
#    'vwap24Hr': '1.6005941483865172',
#    'explorer': 'https://explorer.xinfin.network/'},
#   {'id': 'render-token',
#    'rank': '30',
#    'symbol': 'RNDR',
#    'name': 'Render Token',
#    'supply': '369614008.1087959400000000',
#    'maxSupply': '536870912.0000000000000000',
#    'marketCapUsd': '2227524173.4712388443561784',
#    'volumeUsd24Hr': '9400509.8798264043673865',
#    'priceUsd': '6.0266227053157757',
#    'changePercent24Hr': '-7.4463486444077006',
#    'vwap24Hr': '6.3761295942712525',
#    'explorer': 'https://etherscan.io/token/0x6de037ef9ad2725eb40118bb1702ebb27e4aeb24'},
#   {'id': 'maker',
#    'rank': '31',
#    'symbol': 'MKR',
#    'name': 'Maker',
#    'supply': '930158.7087166800000000',
#    'maxSupply': '1005577.0000000000000000',
#    'marketCapUsd': '2183764546.2011641458848395',
#    'volumeUsd24Hr': '35268036.4141463369537176',
#    'priceUsd': '2347.7332693192296238',
#    'changePercent24Hr': '1.6143170296738990',
#    'vwap24Hr': '2306.9996847830977642',
#    'explorer': 'https://etherscan.io/token/Maker'},
#   {'id': 'vechain',
#    'rank': '32',
#    'symbol': 'VET',
#    'name': 'VeChain',
#    'supply': '80985041177.0000000000000000',
#    'maxSupply': '86712634466.0000000000000000',
#    'marketCapUsd': '2175691709.7815442815483674',
#    'volumeUsd24Hr': '17543035.9649500942150881',
#    'priceUsd': '0.0268653528869162',
#    'changePercent24Hr': '3.5587796691499435',
#    'vwap24Hr': '0.0266669992427982',
#    'explorer': 'https://explore.veforge.com/'},
#   {'id': 'crypto-com-coin',
#    'rank': '33',
#    'symbol': 'CRO',
#    'name': 'Crypto.com Coin',
#    'supply': '25263013692.0000000000000000',
#    'maxSupply': '30263013692.0000000000000000',
#    'marketCapUsd': '2172935029.2054371886771600',
#    'volumeUsd24Hr': '3221505.9231105754518208',
#    'priceUsd': '0.0860125025342300',
#    'changePercent24Hr': '0.9983127782501050',
#    'vwap24Hr': '0.0852406338054745',
#    'explorer': 'https://etherscan.io/token/0xa0b73e1ff0b80914ab6fe0444e65848c4c34450b'},
#   {'id': 'the-graph',
#    'rank': '34',
#    'symbol': 'GRT',
#    'name': 'The Graph',
#    'supply': '9548531509.1654740000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1765443655.8639719406985468',
#    'volumeUsd24Hr': '21055160.1141051254652483',
#    'priceUsd': '0.1848916405804759',
#    'changePercent24Hr': '-0.6737606364739822',
#    'vwap24Hr': '0.1878023942744151',
#    'explorer': 'https://etherscan.io/token/0xc944e90c64b2c07662a292be6244bdf05cda44a7'},
#   {'id': 'arweave',
#    'rank': '35',
#    'symbol': 'AR',
#    'name': 'Arweave',
#    'supply': '65652466.0000000000000000',
#    'maxSupply': '66000000.0000000000000000',
#    'marketCapUsd': '1559463880.6270420755118854',
#    'volumeUsd24Hr': '47987858.1160365134231207',
#    'priceUsd': '23.7533176686317019',
#    'changePercent24Hr': '4.9342437655309172',
#    'vwap24Hr': '23.4252238143581692',
#    'explorer': 'https://viewblock.io/arweave'},
#   {'id': 'cosmos',
#    'rank': '36',
#    'symbol': 'ATOM',
#    'name': 'Cosmos',
#    'supply': '248453201.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1498389512.6381346042483804',
#    'volumeUsd24Hr': '37958105.1525983148843153',
#    'priceUsd': '6.0308722391471004',
#    'changePercent24Hr': '0.2905149190548161',
#    'vwap24Hr': '6.0709632417445042',
#    'explorer': 'https://www.mintscan.io/'},
#   {'id': 'injective-protocol',
#    'rank': '37',
#    'symbol': 'INJ',
#    'name': 'Injective',
#    'supply': '73005554.3300000000000000',
#    'maxSupply': '100000000.0000000000000000',
#    'marketCapUsd': '1463394892.5778730336713294',
#    'volumeUsd24Hr': '23406933.5830352723121051',
#    'priceUsd': '20.0449802211353613',
#    'changePercent24Hr': '-3.3417519551082811',
#    'vwap24Hr': '20.5583737977919500',
#    'explorer': 'https://etherscan.io/token/0xe28b3b32b6c345a34ff64674606124dd5aceca30'},
#   {'id': 'lido-dao',
#    'rank': '38',
#    'symbol': 'LDO',
#    'name': 'Lido DAO',
#    'supply': '892895588.5033206000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1440307562.6676650984292001',
#    'volumeUsd24Hr': '4399747.9790754648091703',
#    'priceUsd': '1.6130750125912496',
#    'changePercent24Hr': '-1.9656027793141367',
#    'vwap24Hr': '1.6491302653691198',
#    'explorer': 'https://etherscan.io/token/0x5a98fcbea516cf06857215779fd812ca3bef1b32'},
#   {'id': 'aave',
#    'rank': '39',
#    'symbol': 'AAVE',
#    'name': 'Aave',
#    'supply': '14871201.6897805100000000',
#    'maxSupply': None,
#    'marketCapUsd': '1387547337.0273346496723266',
#    'volumeUsd24Hr': '42580905.7521260835598280',
#    'priceUsd': '93.3043183713160987',
#    'changePercent24Hr': '3.9035059135892239',
#    'vwap24Hr': '91.6759674597865082',
#    'explorer': 'https://etherscan.io/token/0x80fB784B7eD66730e8b1DBd9820aFD29931aab03'},
#   {'id': 'theta',
#    'rank': '40',
#    'symbol': 'THETA',
#    'name': 'THETA',
#    'supply': '1000000000.0000000000000000',
#    'maxSupply': '1000000000.0000000000000000',
#    'marketCapUsd': '1369840309.6733875000000000',
#    'volumeUsd24Hr': '11009818.4665465658399601',
#    'priceUsd': '1.3698403096733875',
#    'changePercent24Hr': '-0.3801412453130499',
#    'vwap24Hr': '1.3813954806037956',
#    'explorer': 'https://explorer.thetatoken.org/'},
#   {'id': 'fantom',
#    'rank': '41',
#    'symbol': 'FTM',
#    'name': 'Fantom',
#    'supply': '2803634835.5265927000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1310510601.9741792821868022',
#    'volumeUsd24Hr': '39453297.5526322322605076',
#    'priceUsd': '0.4674327003530874',
#    'changePercent24Hr': '-0.1338972482207859',
#    'vwap24Hr': '0.4723144218393612',
#    'explorer': 'https://etherscan.io/token/0x4e15361fd6b4bb609fa63c81a2be19d873717870'},
#   {'id': 'thorchain',
#    'rank': '42',
#    'symbol': 'RUNE',
#    'name': 'THORChain',
#    'supply': '336630813.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1195710817.5860387350699740',
#    'volumeUsd24Hr': '30933780.4262092439224593',
#    'priceUsd': '3.5519945632131980',
#    'changePercent24Hr': '-1.6156319665431751',
#    'vwap24Hr': '3.6345243482582139',
#    'explorer': 'https://explorer.binance.org/asset/RUNE-B1A'},
#   {'id': 'algorand',
#    'rank': '43',
#    'symbol': 'ALGO',
#    'name': 'Algorand',
#    'supply': '8228347431.3279580000000000',
#    'maxSupply': '10000000000.0000000000000000',
#    'marketCapUsd': '1139372533.3394785059749550',
#    'volumeUsd24Hr': '18776121.7907777332588385',
#    'priceUsd': '0.1384691814302252',
#    'changePercent24Hr': '-0.4790257585569007',
#    'vwap24Hr': '0.1394192279470033',
#    'explorer': 'https://algoexplorer.io/'},
#   {'id': 'hedera-hashgraph',
#    'rank': '44',
#    'symbol': 'HBAR',
#    'name': 'Hedera Hashgraph',
#    'supply': '14832756028.0000000000000000',
#    'maxSupply': '50000000000.0000000000000000',
#    'marketCapUsd': '987114408.9953703992819452',
#    'volumeUsd24Hr': '12109489.7520794020638803',
#    'priceUsd': '0.0665496288843409',
#    'changePercent24Hr': '0.9990893681202072',
#    'vwap24Hr': '0.0668174143827602',
#    'explorer': 'https://hash-hash.info/'},
#   {'id': 'elrond-egld',
#    'rank': '45',
#    'symbol': 'EGLD',
#    'name': 'MultiversX',
#    'supply': '24184559.1898415400000000',
#    'maxSupply': '31415926.0000000000000000',
#    'marketCapUsd': '867993763.6581548566752376',
#    'volumeUsd24Hr': '17404206.1280428547186212',
#    'priceUsd': '35.8904107717930273',
#    'changePercent24Hr': '-3.2247562239074058',
#    'vwap24Hr': '36.3660463915790710',
#    'explorer': 'https://explorer.elrond.com/'},
#   {'id': 'kucoin-token',
#    'rank': '46',
#    'symbol': 'KCS',
#    'name': 'KuCoin Token',
#    'supply': '95540492.2885607500000000',
#    'maxSupply': '170118638.0000000000000000',
#    'marketCapUsd': '861186279.4225235811384063',
#    'volumeUsd24Hr': '430965.9301239483168469',
#    'priceUsd': '9.0138354826714149',
#    'changePercent24Hr': '0.9774892849663831',
#    'vwap24Hr': '9.0270309608154138',
#    'explorer': 'https://etherscan.io/token/0xf34960d9d60be18cc1d5afc1a6f012a723a28811'},
#   {'id': 'quant',
#    'rank': '47',
#    'symbol': 'QNT',
#    'name': 'Quant',
#    'supply': '12072738.0000000000000000',
#    'maxSupply': '14881364.0000000000000000',
#    'marketCapUsd': '835874784.1922112593933724',
#    'volumeUsd24Hr': '2352962.6886622466907605',
#    'priceUsd': '69.2365546400668398',
#    'changePercent24Hr': '-0.8426306791138337',
#    'vwap24Hr': '70.0660855336499014',
#    'explorer': 'https://etherscan.io/token/0x4a220e6096b25eadb88358cb44068a3248254675'},
#   {'id': 'flow',
#    'rank': '48',
#    'symbol': 'FLOW',
#    'name': 'Flow',
#    'supply': '1511780104.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '835355869.1970995402945928',
#    'volumeUsd24Hr': '11701410.2721558489974613',
#    'priceUsd': '0.5525644020495057',
#    'changePercent24Hr': '0.2468771088812288',
#    'vwap24Hr': '0.5559492740964847',
#    'explorer': 'https://flowscan.org/'},
#   {'id': 'akash-network',
#    'rank': '49',
#    'symbol': 'AKT',
#    'name': 'Akash Network',
#    'supply': '243869410.3485010000000000',
#    'maxSupply': '388539008.0000000000000000',
#    'marketCapUsd': '821792103.2536313119803444',
#    'volumeUsd24Hr': '4411659.4269515146630092',
#    'priceUsd': '3.3698039540065778',
#    'changePercent24Hr': '-4.4293103720141290',
#    'vwap24Hr': '3.4839194717744521',
#    'explorer': 'https://akash.bigdipper.live/'},
#   {'id': 'axie-infinity',
#    'rank': '50',
#    'symbol': 'AXS',
#    'name': 'Axie Infinity',
#    'supply': '147736585.9704852700000000',
#    'maxSupply': None,
#    'marketCapUsd': '796723988.5694459199893587',
#    'volumeUsd24Hr': '6041012.5506242014899543',
#    'priceUsd': '5.3928685527403143',
#    'changePercent24Hr': '0.9280177496977488',
#    'vwap24Hr': '5.3942544714635559',
#    'explorer': 'https://etherscan.io/token/0xf5d669627376ebd411e34b98f19c868c8aba5ada'},
#   {'id': 'eos',
#    'rank': '51',
#    'symbol': 'EOS',
#    'name': 'EOS',
#    'supply': '1501052610.6137000000000000',
#    'maxSupply': '2100000000.0000000000000000',
#    'marketCapUsd': '792399230.0376359705214598',
#    'volumeUsd24Hr': '37731440.0479089658079859',
#    'priceUsd': '0.5278957076085870',
#    'changePercent24Hr': '0.9873842090584166',
#    'vwap24Hr': '0.5285329468853072',
#    'explorer': 'https://bloks.io/'},
#   {'id': 'bitcoin-sv',
#    'rank': '52',
#    'symbol': 'BSV',
#    'name': 'Bitcoin SV',
#    'supply': '19727468.7500000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '760906294.6616133273346969',
#    'volumeUsd24Hr': '4187513.9701140830381090',
#    'priceUsd': '38.5709035611379857',
#    'changePercent24Hr': '3.1185469023828240',
#    'vwap24Hr': '38.3832406875580925',
#    'explorer': 'https://bsvexplorer.io/'},
#   {'id': 'tezos',
#    'rank': '53',
#    'symbol': 'XTZ',
#    'name': 'Tezos',
#    'supply': '988930690.6436740000000000',
#    'maxSupply': None,
#    'marketCapUsd': '752117999.8543070526639607',
#    'volumeUsd24Hr': '20928784.4204747808070819',
#    'priceUsd': '0.7605366149216882',
#    'changePercent24Hr': '1.9904685507152585',
#    'vwap24Hr': '0.7542939742971911',
#    'explorer': 'https://tzkt.io/'},
#   {'id': 'gala',
#    'rank': '54',
#    'symbol': 'GALA',
#    'name': 'Gala',
#    'supply': '32656491649.9509660000000000',
#    'maxSupply': None,
#    'marketCapUsd': '693696076.4958936675047287',
#    'volumeUsd24Hr': '15759039.2189388450323451',
#    'priceUsd': '0.0212422107044354',
#    'changePercent24Hr': '-7.5647575084047850',
#    'vwap24Hr': '0.0217200981295977',
#    'explorer': 'https://ethplorer.io/es/address/0x15d4c048f83bd7e37d49ea4c83a07267ec4203da#chart=candlestick'},
#   {'id': 'the-sandbox',
#    'rank': '55',
#    'symbol': 'SAND',
#    'name': 'The Sandbox',
#    'supply': '2281231926.2233224000000000',
#    'maxSupply': None,
#    'marketCapUsd': '693587368.2893149729387679',
#    'volumeUsd24Hr': '16255500.9150219609014015',
#    'priceUsd': '0.3040407072671382',
#    'changePercent24Hr': '1.4274373970089643',
#    'vwap24Hr': '0.3026845148352219',
#    'explorer': 'https://etherscan.io/token/0x3845badAde8e6dFF049820680d1F14bD3903a5d0'},
#   {'id': 'neo',
#    'rank': '56',
#    'symbol': 'NEO',
#    'name': 'Neo',
#    'supply': '70538831.0000000000000000',
#    'maxSupply': '100000000.0000000000000000',
#    'marketCapUsd': '691553197.6869612111251577',
#    'volumeUsd24Hr': '7598536.0949754078551804',
#    'priceUsd': '9.8038653020342967',
#    'changePercent24Hr': '0.1883661973988872',
#    'vwap24Hr': '9.9261492497790039',
#    'explorer': 'https://neotracker.io'},
#   {'id': 'gnosis-gno',
#    'rank': '57',
#    'symbol': 'GNO',
#    'name': 'Gnosis',
#    'supply': '2589588.0000000000000000',
#    'maxSupply': '3000000.0000000000000000',
#    'marketCapUsd': '683494325.2337204102683608',
#    'volumeUsd24Hr': '398761.3847746126673254',
#    'priceUsd': '263.9394085984799166',
#    'changePercent24Hr': '0.9378110394138665',
#    'vwap24Hr': '263.4826914874327890',
#    'explorer': 'https://etherscan.io/token/Gnosis'},
#   {'id': 'gatetoken',
#    'rank': '58',
#    'symbol': 'GT',
#    'name': 'GateToken',
#    'supply': '93096874.2769858800000000',
#    'maxSupply': None,
#    'marketCapUsd': '638153859.9081029292225290',
#    'volumeUsd24Hr': '1816687.3015793620253129',
#    'priceUsd': '6.8547291717812108',
#    'changePercent24Hr': '-0.5210582664593453',
#    'vwap24Hr': '6.9124925901506639',
#    'explorer': None},
#   {'id': 'nexo',
#    'rank': '59',
#    'symbol': 'NEXO',
#    'name': 'Nexo',
#    'supply': '560000011.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '621689812.4838210379154074',
#    'volumeUsd24Hr': '787272.6689162946754229',
#    'priceUsd': '1.1101603576286734',
#    'changePercent24Hr': '4.3809736754832980',
#    'vwap24Hr': '1.0835090951844653',
#    'explorer': 'https://etherscan.io/token/0xb62132e35a6c13ee1ee0f84dc5d40bad8d815206'},
#   {'id': 'decentraland',
#    'rank': '60',
#    'symbol': 'MANA',
#    'name': 'Decentraland',
#    'supply': '1908319865.3915880000000000',
#    'maxSupply': None,
#    'marketCapUsd': '610729539.1019273742730380',
#    'volumeUsd24Hr': '8856598.6399243895243110',
#    'priceUsd': '0.3200352048824925',
#    'changePercent24Hr': '2.4966843187974247',
#    'vwap24Hr': '0.3172712027198096',
#    'explorer': 'https://etherscan.io/token/decentraland'},
#   {'id': 'conflux-network',
#    'rank': '61',
#    'symbol': 'CFX',
#    'name': 'Conflux',
#    'supply': '4232510801.2500000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '602542479.9432300750858964',
#    'volumeUsd24Hr': '6896372.3389190354656343',
#    'priceUsd': '0.1423605297747331',
#    'changePercent24Hr': '1.7164961446097644',
#    'vwap24Hr': '0.1417839235579546',
#    'explorer': 'http://www.confluxscan.io/'},
#   {'id': 'ecash',
#    'rank': '62',
#    'symbol': 'XEC',
#    'name': 'eCash',
#    'supply': '19727535923091.0000000000000000',
#    'maxSupply': '21000000000000.0000000000000000',
#    'marketCapUsd': '600465971.4934390511373567',
#    'volumeUsd24Hr': '8249997.9500652974875691',
#    'priceUsd': '0.0000304379611237',
#    'changePercent24Hr': '-2.3756416972436166',
#    'vwap24Hr': '0.0000311832209980',
#    'explorer': 'https://explorer.bitcoinabc.org/'},
#   {'id': 'chiliz',
#    'rank': '63',
#    'symbol': 'CHZ',
#    'name': 'Chiliz',
#    'supply': '8919064798.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '587646539.6491523809469942',
#    'volumeUsd24Hr': '13278317.2940662604142758',
#    'priceUsd': '0.0658865646744629',
#    'changePercent24Hr': '-0.9823926061529980',
#    'vwap24Hr': '0.0668640347389371',
#    'explorer': 'https://etherscan.io/token/0x3506424f91fd33084466f402d5d97f05f8e3b4af'},
#   {'id': 'pendle',
#    'rank': '64',
#    'symbol': 'PENDLE',
#    'name': 'Pendle',
#    'supply': '154928384.5032312600000000',
#    'maxSupply': None,
#    'marketCapUsd': '568523675.5404476689674826',
#    'volumeUsd24Hr': '3600120.4706390705679327',
#    'priceUsd': '3.6695901616955818',
#    'changePercent24Hr': '2.5636980926482782',
#    'vwap24Hr': '3.7130949803343788',
#    'explorer': 'https://etherscan.io/token/0x808507121b80c02388fad14726482e061b8da827'},
#   {'id': 'dexe',
#    'rank': '65',
#    'symbol': 'DEXE',
#    'name': 'DeXe',
#    'supply': '57103225.3406123900000000',
#    'maxSupply': '98942301.0000000000000000',
#    'marketCapUsd': '562386199.9778283133200903',
#    'volumeUsd24Hr': '855819.7182598836598164',
#    'priceUsd': '9.8485890529523833',
#    'changePercent24Hr': '0.7506287368569416',
#    'vwap24Hr': '9.9107178062544794',
#    'explorer': 'https://etherscan.io/token/0xde4EE8057785A7e8e800Db58F9784845A5C2Cbd6'},
#   {'id': 'mina',
#    'rank': '66',
#    'symbol': 'MINA',
#    'name': 'Mina',
#    'supply': '1130803448.8400393000000000',
#    'maxSupply': None,
#    'marketCapUsd': '551727371.2830539213533220',
#    'volumeUsd24Hr': '4674956.1448055295470872',
#    'priceUsd': '0.4879074005734660',
#    'changePercent24Hr': '-1.7647140016226162',
#    'vwap24Hr': '0.4972853208245778',
#    'explorer': 'https://minaexplorer.com/'},
#   {'id': 'klaytn',
#    'rank': '67',
#    'symbol': 'KLAY',
#    'name': 'Klaytn',
#    'supply': '3702511344.3885970000000000',
#    'maxSupply': None,
#    'marketCapUsd': '543625795.9807217882147041',
#    'volumeUsd24Hr': '2644562.4249522588263185',
#    'priceUsd': '0.1468262337142121',
#    'changePercent24Hr': '0.4527351393397051',
#    'vwap24Hr': '0.1475974860645148',
#    'explorer': 'https://scope.klaytn.com/blocks'},
#   {'id': 'mantra-dao',
#    'rank': '68',
#    'symbol': 'OM',
#    'name': 'MANTRA DAO',
#    'supply': '500205033.1781248500000000',
#    'maxSupply': '888888888.0000000000000000',
#    'marketCapUsd': '532983331.8334930698341311',
#    'volumeUsd24Hr': '105824532.5352582948037539',
#    'priceUsd': '1.0655297257748619',
#    'changePercent24Hr': '11.6529167321401255',
#    'vwap24Hr': '1.0792076007490222',
#    'explorer': 'https://etherscan.io/token/0x3593d125a4f7849a1b059e64f4517a86dd60c95d'},
#   {'id': 'oasis-network',
#    'rank': '69',
#    'symbol': 'ROSE',
#    'name': 'Oasis',
#    'supply': '6713599876.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '527032789.9127531784739732',
#    'volumeUsd24Hr': '7155545.5981259723088245',
#    'priceUsd': '0.0785022640084357',
#    'changePercent24Hr': '-3.6340630871463883',
#    'vwap24Hr': '0.0815113559859932',
#    'explorer': 'https://www.oasisscan.com/'},
#   {'id': 'iota',
#    'rank': '70',
#    'symbol': 'IOTA',
#    'name': 'IOTA',
#    'supply': '3344331631.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '519061828.3512127052481707',
#    'volumeUsd24Hr': '3471335.3983800053302018',
#    'priceUsd': '0.1552064464958597',
#    'changePercent24Hr': '0.5940056348726784',
#    'vwap24Hr': '0.1565168624420817',
#    'explorer': 'https://thetangle.org/'},
#   {'id': '1inch',
#    'rank': '71',
#    'symbol': '1INCH',
#    'name': '1inch Network',
#    'supply': '1253536817.6576266000000000',
#    'maxSupply': None,
#    'marketCapUsd': '509460491.2997724927476104',
#    'volumeUsd24Hr': '14551941.0521054152482058',
#    'priceUsd': '0.4064184506776245',
#    'changePercent24Hr': '-0.9704861449107810',
#    'vwap24Hr': '0.4092781748896558',
#    'explorer': 'https://etherscan.io/token/0x111111111117dc0aa78b770fa6a738034120c302'},
#   {'id': 'wemix',
#    'rank': '72',
#    'symbol': 'WEMIX',
#    'name': 'WEMIX',
#    'supply': '407741421.2110001000000000',
#    'maxSupply': '590000000.0000000000000000',
#    'marketCapUsd': '506972302.3971588266102335',
#    'volumeUsd24Hr': '1205521.7706921944348223',
#    'priceUsd': '1.2433671832786599',
#    'changePercent24Hr': '-0.5442904678495724',
#    'vwap24Hr': '1.2492166102531955',
#    'explorer': 'https://scope.klaytn.com/token/0x5096db80b21ef45230c9e423c373f1fc9c0198dd?tabId=kctTransfer'},
#   {'id': 'pancakeswap',
#    'rank': '73',
#    'symbol': 'CAKE',
#    'name': 'PancakeSwap',
#    'supply': '268751835.1245609500000000',
#    'maxSupply': '450000000.0000000000000000',
#    'marketCapUsd': '504371781.8244400360248914',
#    'volumeUsd24Hr': '7133027.9031650238347971',
#    'priceUsd': '1.8767193965044893',
#    'changePercent24Hr': '0.8233677215797019',
#    'vwap24Hr': '1.8857285845929639',
#    'explorer': 'https://bscscan.com/token/0x0e09fabb73bd3ade0a17ecc321fd13a19e81ce82'},
#   {'id': 'helium',
#    'rank': '74',
#    'symbol': 'HNT',
#    'name': 'Helium',
#    'supply': '160875441.8242133300000000',
#    'maxSupply': None,
#    'marketCapUsd': '496891713.4145295804176714',
#    'volumeUsd24Hr': '1627165.0664912199117455',
#    'priceUsd': '3.0886734965892259',
#    'changePercent24Hr': '1.4422923134863280',
#    'vwap24Hr': '3.1120780418160285',
#    'explorer': 'https://explorer.helium.com/'},
#   {'id': 'trueusd',
#    'rank': '75',
#    'symbol': 'TUSD',
#    'name': 'TrueUSD',
#    'supply': '495201532.6100000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '494775941.0718733233601607',
#    'volumeUsd24Hr': '7807192.7780879049945939',
#    'priceUsd': '0.9991405690206903',
#    'changePercent24Hr': '0.0203669026534926',
#    'vwap24Hr': '0.9987558183958361',
#    'explorer': 'https://etherscan.io/token/0x8dd5fbce2f6a956c3022ba3663759011dd51e73e'},
#   {'id': 'raydium',
#    'rank': '76',
#    'symbol': 'RAY',
#    'name': 'Raydium',
#    'supply': '262950204.4623400000000000',
#    'maxSupply': None,
#    'marketCapUsd': '482367223.4215781632565219',
#    'volumeUsd24Hr': '9348918.4981907992461911',
#    'priceUsd': '1.8344432338734435',
#    'changePercent24Hr': '3.1837369801138368',
#    'vwap24Hr': '1.8654916334254731',
#    'explorer': 'https://explorer.solana.com/address/4k3Dyjzvzp8eMZWUXbBCjEvwSkkk59S5iCNLY3QrkX6R'},
#   {'id': 'livepeer',
#    'rank': '77',
#    'symbol': 'LPT',
#    'name': 'Livepeer',
#    'supply': '33265435.6250162200000000',
#    'maxSupply': None,
#    'marketCapUsd': '455574360.3203180374029348',
#    'volumeUsd24Hr': '7910945.9621373781755684',
#    'priceUsd': '13.6951268414389178',
#    'changePercent24Hr': '2.3302081597824457',
#    'vwap24Hr': '13.9424592472436470',
#    'explorer': 'https://explorer.livepeer.org/'},
#   {'id': 'nxm',
#    'rank': '78',
#    'symbol': 'NXM',
#    'name': 'NXM',
#    'supply': '6594067.8412913900000000',
#    'maxSupply': None,
#    'marketCapUsd': '455567718.0730197546499736',
#    'volumeUsd24Hr': '185532.5553382427152454',
#    'priceUsd': '69.0875085057967552',
#    'changePercent24Hr': '1.2971989449223143',
#    'vwap24Hr': '67.9871163642699906',
#    'explorer': 'https://etherscan.io/token/0xd7c49cee7e9188cca6ad8ff264c1da2e69d4cf3b'},
#   {'id': 'aioz-network',
#    'rank': '79',
#    'symbol': 'AIOZ',
#    'name': 'AIOZ Network',
#    'supply': '1106724244.5711417000000000',
#    'maxSupply': None,
#    'marketCapUsd': '453024597.7768899236941294',
#    'volumeUsd24Hr': '1855173.5838080320537293',
#    'priceUsd': '0.4093382791595372',
#    'changePercent24Hr': '-3.7517060842357702',
#    'vwap24Hr': '0.4211184378952850',
#    'explorer': 'https://etherscan.io/token/0x626e8036deb333b408be468f951bdb42433cbf18'},
#   {'id': 'nervos-network',
#    'rank': '80',
#    'symbol': 'CKB',
#    'name': 'Nervos Network',
#    'supply': '44535188285.3494800000000000',
#    'maxSupply': None,
#    'marketCapUsd': '442978500.8516574747887190',
#    'volumeUsd24Hr': '9229362.1881751048335381',
#    'priceUsd': '0.0099467077137604',
#    'changePercent24Hr': '-0.3321858328435904',
#    'vwap24Hr': '0.0101246045606544',
#    'explorer': 'https://explorer.nervos.org/'},
#   {'id': 'theta-fuel',
#    'rank': '81',
#    'symbol': 'TFUEL',
#    'name': 'Theta Fuel',
#    'supply': '6610459080.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '434565668.2945236443689560',
#    'volumeUsd24Hr': '840504.9816242673820864',
#    'priceUsd': '0.0657391057164707',
#    'changePercent24Hr': '-0.1377453998853427',
#    'vwap24Hr': '0.0660936890979277',
#    'explorer': 'https://explorer.thetatoken.org/'},
#   {'id': 'trust-wallet-token',
#    'rank': '82',
#    'symbol': 'TWT',
#    'name': 'Trust Wallet Token',
#    'supply': '416649900.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '424908530.0874480600769200',
#    'volumeUsd24Hr': '1616493.0139045229150080',
#    'priceUsd': '1.0198215098274308',
#    'changePercent24Hr': '0.1645915265877939',
#    'vwap24Hr': '1.0261335914076007',
#    'explorer': 'https://explorer.binance.org/asset/TWT-8C2'},
#   {'id': 'kava',
#    'rank': '83',
#    'symbol': 'KAVA',
#    'name': 'Kava',
#    'supply': '1082856129.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '422335067.3095008796196724',
#    'volumeUsd24Hr': '2714221.6545423022730664',
#    'priceUsd': '0.3900195566141556',
#    'changePercent24Hr': '0.4555363944488895',
#    'vwap24Hr': '0.3904555943539933',
#    'explorer': 'https://www.mintscan.io/kava'},
#   {'id': 'zcash',
#    'rank': '84',
#    'symbol': 'ZEC',
#    'name': 'Zcash',
#    'supply': '16328268.7500000000000000',
#    'maxSupply': '21000000.0000000000000000',
#    'marketCapUsd': '395707533.7281521222253150',
#    'volumeUsd24Hr': '45223958.2330663967918468',
#    'priceUsd': '24.2345064125767848',
#    'changePercent24Hr': '4.9759398496750619',
#    'vwap24Hr': '23.7012579161937900',
#    'explorer': 'https://explorer.zcha.in/'},
#   {'id': 'compound',
#    'rank': '85',
#    'symbol': 'COMP',
#    'name': 'Compound',
#    'supply': '8359584.4865648100000000',
#    'maxSupply': None,
#    'marketCapUsd': '394897286.8613663292971765',
#    'volumeUsd24Hr': '11137783.1151075188387117',
#    'priceUsd': '47.2388654598837373',
#    'changePercent24Hr': '-1.5276088124701288',
#    'vwap24Hr': '47.9394221210705472',
#    'explorer': 'https://etherscan.io/token/0xc00e94cb662c3520282e6f5717214004a7f26888'},
#   {'id': 'ftx-token',
#    'rank': '86',
#    'symbol': 'FTT',
#    'name': 'FTX Token',
#    'supply': '328895103.8132070000000000',
#    'maxSupply': None,
#    'marketCapUsd': '394013202.3208836304286634',
#    'volumeUsd24Hr': '7162418.8613274264489382',
#    'priceUsd': '1.1979904770630452',
#    'changePercent24Hr': '0.4485198794505683',
#    'vwap24Hr': '1.1957267509698836',
#    'explorer': 'https://etherscan.io/token/0x50d1c9771902476076ecfc8b2a83ad6b9355a4c9'},
#   {'id': 'synthetix-network-token',
#    'rank': '87',
#    'symbol': 'SNX',
#    'name': 'Synthetix',
#    'supply': '233716733.4900000000000000',
#    'maxSupply': '212424133.0000000000000000',
#    'marketCapUsd': '385894100.7402629643910866',
#    'volumeUsd24Hr': '11191745.8403896459629613',
#    'priceUsd': '1.6511188350866377',
#    'changePercent24Hr': '0.6474285247148439',
#    'vwap24Hr': '1.6515281568560125',
#    'explorer': 'https://etherscan.io/token/0xc011a72400e58ecd99ee497cf89e3775d4bd732f'},
#   {'id': 'xinfin-network',
#    'rank': '88',
#    'symbol': 'XDC',
#    'name': 'XinFin Network',
#    'supply': '12293293518.5500000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '354351546.5455330968509012',
#    'volumeUsd24Hr': '1437508.5542523445389149',
#    'priceUsd': '0.0288247853198033',
#    'changePercent24Hr': '2.5362671402603374',
#    'vwap24Hr': '0.0286042707749177',
#    'explorer': 'https://etherscan.io/token/0x41ab1b6fcbb2fa9dced81acbdec13ea6315f2bf2'},
#   {'id': 'wootrade',
#    'rank': '89',
#    'symbol': 'WOO',
#    'name': 'WOO',
#    'supply': '1914986376.6880167000000000',
#    'maxSupply': None,
#    'marketCapUsd': '347360057.5890893308424263',
#    'volumeUsd24Hr': '11558896.6013521310698864',
#    'priceUsd': '0.1813903544263595',
#    'changePercent24Hr': '-1.6221867202344114',
#    'vwap24Hr': '0.1843253076970300',
#    'explorer': 'https://etherscan.io/token/0x4691937a7508860f876c9c0a2a617e7d9e945d4b'},
#   {'id': 'aragon',
#    'rank': '90',
#    'symbol': 'ANT',
#    'name': 'Aragon',
#    'supply': '43191429.8753035100000000',
#    'maxSupply': None,
#    'marketCapUsd': '342160138.5315139105794124',
#    'volumeUsd24Hr': '566531.8635077972780892',
#    'priceUsd': '7.9219451525303206',
#    'changePercent24Hr': '0.8677875974013237',
#    'vwap24Hr': '7.8945556290725548',
#    'explorer': 'https://etherscan.io/token/Aragon'},
#   {'id': 'iotex',
#    'rank': '91',
#    'symbol': 'IOTX',
#    'name': 'IoTeX',
#    'supply': '9441378929.0000000000000000',
#    'maxSupply': '10000000000.0000000000000000',
#    'marketCapUsd': '342032305.5088757089315209',
#    'volumeUsd24Hr': '2832886.7036875647637345',
#    'priceUsd': '0.0362269439751321',
#    'changePercent24Hr': '-2.8682901853213291',
#    'vwap24Hr': '0.0371834848553787',
#    'explorer': 'https://etherscan.io/token/0x6fb3e0a217407efff7ca062d46c26e5d60a14d69'},
#   {'id': 'curve-dao-token',
#    'rank': '92',
#    'symbol': 'CRV',
#    'name': 'Curve DAO Token',
#    'supply': '1192334337.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '322824339.8342549600558454',
#    'volumeUsd24Hr': '9530130.3804614398497178',
#    'priceUsd': '0.2707498474349942',
#    'changePercent24Hr': '-7.1180803739880734',
#    'vwap24Hr': '0.2864681983433602',
#    'explorer': 'https://etherscan.io/token/0xD533a949740bb3306d119CC777fa900bA034cd52'},
#   {'id': 'kusama',
#    'rank': '93',
#    'symbol': 'KSM',
#    'name': 'Kusama',
#    'supply': '15194161.9749454900000000',
#    'maxSupply': None,
#    'marketCapUsd': '319033528.0569843611917787',
#    'volumeUsd24Hr': '2074610.2747881832894550',
#    'priceUsd': '20.9971124819556831',
#    'changePercent24Hr': '0.0289175053503011',
#    'vwap24Hr': '21.1397388132738554',
#    'explorer': 'https://kusama.subscan.io/'},
#   {'id': 'golem-network-tokens',
#    'rank': '94',
#    'symbol': 'GLM',
#    'name': 'Golem',
#    'supply': '1000000000.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '311078482.5319084000000000',
#    'volumeUsd24Hr': '179920.2002288162873194',
#    'priceUsd': '0.3110784825319084',
#    'changePercent24Hr': '-1.4189005615843308',
#    'vwap24Hr': '0.3157739735812364',
#    'explorer': 'https://etherscan.io/token/Golem'},
#   {'id': 'zilliqa',
#    'rank': '95',
#    'symbol': 'ZIL',
#    'name': 'Zilliqa',
#    'supply': '18684832691.2061040000000000',
#    'maxSupply': '21000000000.0000000000000000',
#    'marketCapUsd': '291043063.2300744513728604',
#    'volumeUsd24Hr': '5693956.4272709984893925',
#    'priceUsd': '0.0155764340007739',
#    'changePercent24Hr': '-1.1577999523604741',
#    'vwap24Hr': '0.0157216231562899',
#    'explorer': 'https://etherscan.io/token/0x05f4a42e251f2d52b8ed15e9fedaacfcef1fad27'},
#   {'id': 'dash',
#    'rank': '96',
#    'symbol': 'DASH',
#    'name': 'Dash',
#    'supply': '11874253.8800896800000000',
#    'maxSupply': '18900000.0000000000000000',
#    'marketCapUsd': '285978202.2533985780382265',
#    'volumeUsd24Hr': '18764975.2425572389764394',
#    'priceUsd': '24.0838881449988616',
#    'changePercent24Hr': '1.2356361710734102',
#    'vwap24Hr': '23.8597048533065374',
#    'explorer': 'https://explorer.dash.org'},
#   {'id': 'illuvium',
#    'rank': '97',
#    'symbol': 'ILV',
#    'name': 'Illuvium',
#    'supply': '4471878.2080871400000000',
#    'maxSupply': None,
#    'marketCapUsd': '283658507.1825249167909710',
#    'volumeUsd24Hr': '5248407.7637400652351619',
#    'priceUsd': '63.4316262615436339',
#    'changePercent24Hr': '6.4279831870865064',
#    'vwap24Hr': '62.1758280473796022',
#    'explorer': 'https://etherscan.io/token/0x767fe9edc9e0df98e07454847909b5e959d7ca0e'},
#   {'id': 'celo',
#    'rank': '98',
#    'symbol': 'CELO',
#    'name': 'Celo',
#    'supply': '542396781.0000000000000000',
#    'maxSupply': '1000000000.0000000000000000',
#    'marketCapUsd': '283432331.6189985063739419',
#    'volumeUsd24Hr': '2273886.7330957019197321',
#    'priceUsd': '0.5225553350380199',
#    'changePercent24Hr': '-0.2657887764212843',
#    'vwap24Hr': '0.5270111719497363',
#    'explorer': 'https://explorer.celo.org/blocks'},
#   {'id': 'just',
#    'rank': '99',
#    'symbol': 'JST',
#    'name': 'JUST',
#    'supply': '9900000000.0000000000000000',
#    'maxSupply': '9900000000.0000000000000000',
#    'marketCapUsd': '282413488.7033618400000000',
#    'volumeUsd24Hr': '5019740.3075765584778711',
#    'priceUsd': '0.0285266150205416',
#    'changePercent24Hr': '0.3092732351344825',
#    'vwap24Hr': '0.0285700539013074',
#    'explorer': 'https://tronscan.org/#/token20/TCFLL5dx5ZJdKnWuesXxi1VPwjLVmWZZy9'},
#   {'id': 'aelf',
#    'rank': '100',
#    'symbol': 'ELF',
#    'name': 'aelf',
#    'supply': '731609229.9091900000000000',
#    'maxSupply': '1000000000.0000000000000000',
#    'marketCapUsd': '277962809.8896156531751888',
#    'volumeUsd24Hr': '8556090.0389448884052118',
#    'priceUsd': '0.3799334378601503',
#    'changePercent24Hr': '-4.0405693575621860',
#    'vwap24Hr': '0.3862829959711248',
#    'explorer': 'https://etherscan.io/token/0xbf2179859fc6D5BEE9Bf9158632Dc51678a4100e'}],
#  'timestamp': 1720728792831}

# %%
pd.DataFrame(response.json()['data'])
# Out:
#               id rank symbol      name                         supply  \
# 0        bitcoin    1    BTC   Bitcoin      19719981.0000000000000000
# 1       ethereum    2    ETH  Ethereum     120209171.4182295800000000
# 2         tether    3   USDT    Tether  112259808785.1427800000000000
# 3   binance-coin    4    BNB       BNB     166801148.0000000000000000
# 4         solana    5    SOL    Solana     463960292.5906939500000000
# ..           ...  ...    ...       ...                            ...
# 95          dash   96   DASH      Dash      11874253.8800896800000000
# 96      illuvium   97    ILV  Illuvium       4471878.2080871400000000
# 97          celo   98   CELO      Celo     542396781.0000000000000000
# 98          just   99    JST      JUST    9900000000.0000000000000000
# 99          aelf  100    ELF      aelf     731609229.9091900000000000
#
#                       maxSupply                    marketCapUsd  \
# 0     21000000.0000000000000000  1134009832338.0065305214175978
# 1                          None   374418791731.4609034481505373
# 2                          None   112325975695.2843195725085213
# 3    166801148.0000000000000000    87729530955.1285150002027308
# 4                          None    63710804350.0946055823147606
# ..                          ...                             ...
# 95    18900000.0000000000000000      285978202.2533985780382265
# 96                         None      283658507.1825249167909710
# 97  1000000000.0000000000000000      283432331.6189985063739419
# 98  9900000000.0000000000000000      282413488.7033618400000000
# 99  1000000000.0000000000000000      277962809.8896156531751888
#
#                    volumeUsd24Hr                priceUsd    changePercent24Hr  \
# 0   11498840489.1653368480747578  57505.6249972049430738   0.0751097233134673
# 1    7839490709.5883600922375026   3114.7273316508421784   0.2668966572573288
# 2   14929475226.6693824492293595      1.0005894087194481   0.0197085115839986
# 3     294138518.8807696699419142    525.9528007272978421   0.4462434656171022
# 4     689868112.5118536482234487    137.3195192940795811  -2.8521368290586593
# ..                           ...                     ...                  ...
# 95     18764975.2425572389764394     24.0838881449988616   1.2356361710734102
# 96      5248407.7637400652351619     63.4316262615436339   6.4279831870865064
# 97      2273886.7330957019197321      0.5225553350380199  -0.2657887764212843
# 98      5019740.3075765584778711      0.0285266150205416   0.3092732351344825
# 99      8556090.0389448884052118      0.3799334378601503  -4.0405693575621860
#
#                   vwap24Hr                                           explorer
# 0   58109.9663121234943209                           https://blockchain.info/
# 1    3131.2178350280849755                              https://etherscan.io/
# 2       1.0002086623431707             https://www.omniexplorer.info/asset/31
# 3     530.7011370922360641  https://etherscan.io/token/0xB8c77482e45F1F44d...
# 4     141.2464694532299801                       https://explorer.solana.com/
# ..                     ...                                                ...
# 95     23.8597048533065374                          https://explorer.dash.org
# 96     62.1758280473796022  https://etherscan.io/token/0x767fe9edc9e0df98e...
# 97      0.5270111719497363                   https://explorer.celo.org/blocks
# 98      0.0285700539013074  https://tronscan.org/#/token20/TCFLL5dx5ZJdKnW...
# 99      0.3862829959711248  https://etherscan.io/token/0xbf2179859fc6D5BEE...
#
# [100 rows x 12 columns]

# %%
data = response.json()

records = []

for item in data['data']:
    records.append(item)

df = pd.DataFrame(records)

df
# Out:
#               id rank symbol      name                         supply  \
# 0        bitcoin    1    BTC   Bitcoin      19719981.0000000000000000
# 1       ethereum    2    ETH  Ethereum     120209171.4182295800000000
# 2         tether    3   USDT    Tether  112259808785.1427800000000000
# 3   binance-coin    4    BNB       BNB     166801148.0000000000000000
# 4         solana    5    SOL    Solana     463960292.5906939500000000
# ..           ...  ...    ...       ...                            ...
# 95          dash   96   DASH      Dash      11874253.8800896800000000
# 96      illuvium   97    ILV  Illuvium       4471878.2080871400000000
# 97          celo   98   CELO      Celo     542396781.0000000000000000
# 98          just   99    JST      JUST    9900000000.0000000000000000
# 99          aelf  100    ELF      aelf     731609229.9091900000000000
#
#                       maxSupply                    marketCapUsd  \
# 0     21000000.0000000000000000  1134009832338.0065305214175978
# 1                          None   374418791731.4609034481505373
# 2                          None   112325975695.2843195725085213
# 3    166801148.0000000000000000    87729530955.1285150002027308
# 4                          None    63710804350.0946055823147606
# ..                          ...                             ...
# 95    18900000.0000000000000000      285978202.2533985780382265
# 96                         None      283658507.1825249167909710
# 97  1000000000.0000000000000000      283432331.6189985063739419
# 98  9900000000.0000000000000000      282413488.7033618400000000
# 99  1000000000.0000000000000000      277962809.8896156531751888
#
#                    volumeUsd24Hr                priceUsd    changePercent24Hr  \
# 0   11498840489.1653368480747578  57505.6249972049430738   0.0751097233134673
# 1    7839490709.5883600922375026   3114.7273316508421784   0.2668966572573288
# 2   14929475226.6693824492293595      1.0005894087194481   0.0197085115839986
# 3     294138518.8807696699419142    525.9528007272978421   0.4462434656171022
# 4     689868112.5118536482234487    137.3195192940795811  -2.8521368290586593
# ..                           ...                     ...                  ...
# 95     18764975.2425572389764394     24.0838881449988616   1.2356361710734102
# 96      5248407.7637400652351619     63.4316262615436339   6.4279831870865064
# 97      2273886.7330957019197321      0.5225553350380199  -0.2657887764212843
# 98      5019740.3075765584778711      0.0285266150205416   0.3092732351344825
# 99      8556090.0389448884052118      0.3799334378601503  -4.0405693575621860
#
#                   vwap24Hr                                           explorer
# 0   58109.9663121234943209                           https://blockchain.info/
# 1    3131.2178350280849755                              https://etherscan.io/
# 2       1.0002086623431707             https://www.omniexplorer.info/asset/31
# 3     530.7011370922360641  https://etherscan.io/token/0xB8c77482e45F1F44d...
# 4     141.2464694532299801                       https://explorer.solana.com/
# ..                     ...                                                ...
# 95     23.8597048533065374                          https://explorer.dash.org
# 96     62.1758280473796022  https://etherscan.io/token/0x767fe9edc9e0df98e...
# 97      0.5270111719497363                   https://explorer.celo.org/blocks
# 98      0.0285700539013074  https://tronscan.org/#/token20/TCFLL5dx5ZJdKnW...
# 99      0.3862829959711248  https://etherscan.io/token/0xbf2179859fc6D5BEE...
#
# [100 rows x 12 columns]
